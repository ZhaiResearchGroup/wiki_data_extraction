# %%
from subprocess import call
import pandas as pd
import numpy as np
import scipy as sp
import pickle

import metapy
from sklearn.feature_extraction.text import TfidfVectorizer

# %% [markdown]
# Read in our original data

# %%
df_docs = pd.read_csv("data/wiki_documents.csv")
df_docs.head()
# Out:
#    Unnamed: 0                 Titles  \
# 0           0         James Bond.txt
# 1           1              Speed.txt
# 2           2  Official language.txt
# 3           3   Federal Register.txt
# 4           4       Flash memory.txt
#
#                                            Documents  \
# 0  This article is about the spy series in genera...
# 1  This article is about the property of moving b...
# 2  An official language is a language that is giv...
# 3  Federal Register. Cover. Type. Daily official ...
# 4  For the neuropsychological concept related to ...
#
#                                  Tokenized Documents
# 0  ['This article is about the spy series in gene...
# 1  ['This article is about the property of moving...
# 2  ['An official language is a language that is g...
# 3  ['Federal Register', 'Cover', 'Type', 'Daily o...
# 4  ['For the neuropsychological concept related t...

# %%
df_summs = pd.read_csv("data/wiki_summaries.csv")
df_summs.head()
# Out:
#    Unnamed: 0                 Titles  \
# 0           0         James Bond.txt
# 1           1              Speed.txt
# 2           2  Official language.txt
# 3           3   Federal Register.txt
# 4           4       Flash memory.txt
#
#                                            Summaries  \
# 0  The James Bond series focuses on a fictional B...
# 1  In everyday use and in kinematics, the speed o...
# 2  An official language is a language that is giv...
# 3  The Federal Register (FR or sometimes Fed. Reg...
# 4  Flash memory is an electronic (solid-state) no...
#
#                                  Tokenized Summaries
# 0  ["The James Bond series focuses on a fictional...
# 1  ['In everyday use and in kinematics, the speed...
# 2  ['An official language is a language that is g...
# 3  ['The Federal Register (FR or sometimes Fed. R...
# 4  ['Flash memory is an electronic (solid-state) ...

# %%
df_summs.shape
# Out:
# (8650, 4)

# %% [markdown]
# Train our Vectorizer to fit the corpus

# %%
corpus = df_docs['Documents'].tolist()

vectorizer = TfidfVectorizer()
vectorizer.fit_transform(corpus)
# Out:
# <8650x1001117 sparse matrix of type '<class 'numpy.float64'>'
# 	with 18827210 stored elements in Compressed Sparse Row format>

# %%
# transform our raw queries using tf idf
def transform_query(raw_query):
    combined_query = ". ".join(raw_query) + "."
    sparse_query = vectorizer.transform([combined_query])
    return sparse_query

# %% [markdown]
# Extract the queries using MeTaPy

# %%
def write_doc(document, filename):
    sentences = [sentence.strip() for sentence in document.split(".")]
    
    # get rid of empty strings: https://stackoverflow.com/questions/3845423/remove-empty-strings-from-a-list-of-strings
    sentences = list(filter(None, sentences))

    # write document to file
    with open(filename, 'w+') as doc_file:
        for sentence in sentences:
            doc_file.write("{}\n".format(sentence))
    
    # write metadata
    with open('wiki/metadata.dat', 'w+') as meta_file:
        for i in range(len(sentences)):
            meta_file.write("SEN{}\n".format(i))

def remove_old_idx():
    call(["rm", "-r", "idx"])
    
def get_stringified_list(idx, search_results):
    return [idx.metadata(doc_id).get('content') for (doc_id, score) in search_results]

def search(document, summary):
    write_doc(document, 'wiki/wiki.dat')
    remove_old_idx()
    
    idx = metapy.index.make_inverted_index('config.toml')
    
    ranker = metapy.index.OkapiBM25()
    
    query = metapy.index.Document()
    query.content(summary)
    
    search_results = ranker.score(idx, query, num_results=5)
    return get_stringified_list(idx, search_results)

document = df_docs.loc[df_docs['Titles'] == 'James Bond.txt', 'Documents'].iloc[0]
summary = df_summs.loc[df_summs['Titles'] == 'James Bond.txt', 'Summaries'].iloc[0]

print(summary)
search(document, summary)
# Out:
# The James Bond series focuses on a fictional British Secret Service agent created in 1953 by writer Ian Fleming, who featured him in twelve novels and two short-story collections. Since Fleming's death in 1964, eight other authors have written authorised Bond novels or novelizations: Kingsley Amis, Christopher Wood, John Gardner, Raymond Benson, Sebastian Faulks, Jeffery Deaver, William Boyd and Anthony Horowitz. The latest novel is Trigger Mortis by Anthony Horowitz, published in September 2015. Additionally Charlie Higson wrote a series on a young James Bond, and Kate Westbrook wrote three novels based on the diaries of a recurring series character, Moneypenny.. The character has also been adapted for television, radio, comic strip, video games and film. The films are the longest continually running film series of all time and have grossed over $7.040 billion in total, making it the fourth-highest-grossing film series to date, which started in 1962 with Dr. No, starring Sean Connery as Bond. As of 2018, there have been twenty-four films in the Eon Productions series. The most recent Bond film, Spectre (2015), stars Daniel Craig in his fourth portrayal of Bond; he is the sixth actor to play Bond in the Eon series. There have also been two independent productions of Bond films: Casino Royale (a 1967 spoof) and Never Say Never Again (a 1983 remake of an earlier Eon-produced film, Thunderball). In 2015 the series was estimated to be worth $19.9 billion,[1] making James Bond one of the highest-grossing media franchises of all time.. The Bond films are renowned for a number of features, including the musical accompaniment, with the theme songs having received Academy Award nominations on several occasions, and two wins. Other important elements which run through most of the films include Bond's cars, his guns, and the gadgets with which he is supplied by Q Branch. The films are also noted for Bond's relationships with various women, who are sometimes referred to as "Bond girls".
# ['As of 2018, there have been twenty-four films in the Eon Productions series',
#  'The most recent Bond film, Spectre (2015), stars Daniel Craig in his fourth portrayal of Bond; he is the sixth actor to play Bond in the Eon series',
#  '040 billion in total, making it the fourth-highest-grossing film series to date, which started in 1962 with Dr',
#  'The Bond films are renowned for a number of features, including the musical accompaniment, with the theme songs having received Academy Award nominations on several occasions, and two wins',
#  'Additionally Charlie Higson wrote a series on a young James Bond, and Kate Westbrook wrote three novels based on the diaries of a recurring series character, Moneypenny']

# %% [markdown]
# Generate raw and transform queries

# %%
def generate_queries():
    data = {"Titles": [], "Raw Query": [], "Query Index": []}
    
    queries = []

    queries_generated = 0
    total_queries = df_summs.shape[0]

    for title in df_summs['Titles']:
        summary = df_summs.loc[df_summs['Titles'] == title, 'Summaries'].iloc[0]
        document = df_docs.loc[df_docs['Titles'] == title, 'Documents'].iloc[0]

        # extract query
        raw_query = search(document, summary)
        query = transform_query(raw_query)
        
        # add query info to data
        data["Titles"].append(title)
        data["Raw Query"].append(raw_query)
        data["Query Index"].append(queries_generated)
        queries.append(query)
        
        queries_generated += 1
        
        if queries_generated % 400 == 0:
            print("Generated {} queries, {:.4f}% complete".format(queries_generated, queries_generated/total_queries * 100))
    
    print("Finished generating queries")

    return pd.DataFrame(data=data), sp.sparse.vstack(queries)

df_queries, queries = generate_queries()

print(queries.shape)
df_queries
# Out:
# Generated 400 queries, 0.0462% complete
# Generated 800 queries, 0.0925% complete
# Generated 1200 queries, 0.1387% complete
# Generated 1600 queries, 0.1850% complete
# Generated 2000 queries, 0.2312% complete
# Generated 2400 queries, 0.2775% complete
# Generated 2800 queries, 0.3237% complete
# Generated 3200 queries, 0.3699% complete
# Generated 3600 queries, 0.4162% complete
# Generated 4000 queries, 0.4624% complete
# Generated 4400 queries, 0.5087% complete
# Generated 4800 queries, 0.5549% complete
# Generated 5200 queries, 0.6012% complete
# Generated 5600 queries, 0.6474% complete
# Generated 6000 queries, 0.6936% complete
# Generated 6400 queries, 0.7399% complete
# Generated 6800 queries, 0.7861% complete
# Generated 7200 queries, 0.8324% complete
# Generated 7600 queries, 0.8786% complete
# Generated 8000 queries, 0.9249% complete
# Generated 8400 queries, 0.9711% complete
# Finished generating queries
# (8650, 1001117)
#       Query Index                                          Raw Query  \
# 0               0  [As of 2018, there have been twenty-four films...
# 1               1  [[1] The average speed of an object in an inte...
# 2               2  [[1] Since "the means of expression of a peopl...
# 3               3  [The Federal Register is compiled by the Offic...
# 4               4  [Although flash memory is technically a type o...
# 5               5  [The aims of the county administrative board i...
# 6               6  [The Twentieth United States Census, conducted...
# 7               7  [On the other hand, keyboard instruments, such...
# 8               8  [South Australia shares borders with all of th...
# 9               9  [Colorado is bordered by Wyoming to the north,...
# 10             10  [The term covers Canada, Australia, New Zealan...
# 11             11  [All tornadoes in the US, 1950–2013, plotted b...
# 12             12  [It was launched in 1997, and was the fifth na...
# 13             13  [Beside these and the insular Scandinavian lan...
# 14             14  [In phonetics, a nasal, also called a nasal oc...
# 15             15  [WebCite is an on-demand archiving service, de...
# 16             16  [Two centuries after that, towards the end of ...
# 17             17  [[9] Although the Austrian School has been con...
# 18             18  [The United States has also seen documented fo...
# 19             19  [The use of names, as the many different kinds...
# 20             20  [Private schools, also known as independent sc...
# 21             21  [The Gastropoda or gastropods, more commonly k...
# 22             22  [The coat of arms on an escutcheon forms the c...
# 23             23  [They were previously placed in a separate sup...
# 24             24  [[9] In 1984, he began referring to his backup...
# 25             25  [Chancellor of the Exchequer, Chancellor of th...
# 26             26  [Some use the term chromosome in a wider sense...
# 27             27  [The Serbian language is official in Serbia, c...
# 28             28  [[2] In some contexts, the word "thesis" or a ...
# 29             29  [Ivan III further consolidated the state durin...
# ...           ...                                                ...
# 8620         8620  [The three modern orders of amphibians are Anu...
# 8621         8621  [Religion is a key element of the D&D game, si...
# 8622         8622  [The Internet Archive allows the public to upl...
# 8623         8623  [External factors such as climate, the parent ...
# 8624         8624  [It is the largest city in KwaZulu-Natal which...
# 8625         8625  [Karlsruhe (German pronunciation: [ˈkaɐ̯lsˌʁuː...
# 8626         8626  [During this period Intel became the dominant ...
# 8627         8627  [Earlier editions were called Anatomy: Descrip...
# 8628         8628  ["[4] There are separate national archives for...
# 8629         8629  [This National Park Service list is complete t...
# 8630         8630  [The island has several informal names: "Garde...
# 8631         8631  [In economics, a service is a transaction in w...
# 8632         8632  [A town may be correctly described as a "marke...
# 8633         8633  [SKOS is part of the Semantic Web family of st...
# 8634         8634  [European Union roaming regulations (sometimes...
# 8635         8635  [It is the ratio of runs conceded per wickets ...
# 8636         8636  [745, enacted July 30, 2002), also known as th...
# 8637         8637  [As of 2009, Lille had a population of 226,827...
# 8638         8638  [[1] Bacterial STIs include chlamydia, gonorrh...
# 8639         8639  [His career falls naturally into three phases ...
# 8640         8640  [The Dictionary of National Biography (DNB) is...
# 8641         8641  [[11] With a population of 298,800, Cincinnati...
# 8642         8642  [General relativity (GR, also known as the gen...
# 8643         8643  [The most common of these is Diet Coke, along ...
# 8644         8644  [Hangzhou is classified as a sub-provincial ci...
# 8645         8645  [In addition to facilitating the reproduction ...
# 8646         8646  [In Europe, the concept of banknotes was first...
# 8647         8647  [United States territory is any extent of regi...
# 8648         8648  [The capital of the Bouches-du-Rhône departmen...
# 8649         8649  [The Tsardom of Russia (Русское царство,[2][3]...
#
#                                                  Titles
# 0                                        James Bond.txt
# 1                                             Speed.txt
# 2                                 Official language.txt
# 3                                  Federal Register.txt
# 4                                      Flash memory.txt
# 5                                Counties of Sweden.txt
# 6                         1980 United States Census.txt
# 7                             Percussion instrument.txt
# 8                                   South Australia.txt
# 9                                          Colorado.txt
# 10                                      Anglosphere.txt
# 11                                          Tornado.txt
# 12                                   Channel 5 (UK).txt
# 13                                 Nordic countries.txt
# 14                                  Nasal consonant.txt
# 15                                          WebCite.txt
# 16                                   Roman Republic.txt
# 17                                  Austrian School.txt
# 18                       Music of the United States.txt
# 19                                     Nomenclature.txt
# 20                                   Private school.txt
# 21                                        Gastropod.txt
# 22                                     Coat of arms.txt
# 23                              Skipper (butterfly).txt
# 24                                Prince (musician).txt
# 25                      Chancellor of the Exchequer.txt
# 26                                       Chromosome.txt
# 27                                            Serbs.txt
# 28                                           Thesis.txt
# 29                            Grand Duchy of Moscow.txt
# ...                                                 ...
# 8620                                       Amphibia.txt
# 8621       List of Dungeons & Dragons creatures (A).txt
# 8622                               Internet Archive.txt
# 8623                                      Ecosystem.txt
# 8624                                         Durban.txt
# 8625                                      Karlsruhe.txt
# 8626                                          Intel.txt
# 8627                                 Gray's Anatomy.txt
# 8628         The National Archives (United Kingdom).txt
# 8629  National Register of Historic Places listings ...
# 8630                           Prince Edward Island.txt
# 8631                            Service (economics).txt
# 8632                                    Market town.txt
# 8633           Simple Knowledge Organization System.txt
# 8634             European Union roaming regulations.txt
# 8635                                Bowling average.txt
# 8636                             Sarbanes–Oxley Act.txt
# 8637                                          Lille.txt
# 8638                   Sexually transmitted disease.txt
# 8639                                        Raphael.txt
# 8640               Dictionary of National Biography.txt
# 8641                               Cincinnati, Ohio.txt
# 8642                             General relativity.txt
# 8643                                      Coca-Cola.txt
# 8644                                       Hangzhou.txt
# 8645                                         Flower.txt
# 8646                                       Banknote.txt
# 8647                        United States territory.txt
# 8648                                      Marseille.txt
# 8649                              Tsardom of Russia.txt
#
# [8650 rows x 3 columns]

# %% [markdown]
# Merge all the dataframes together

# %%
df_summs_short = df_summs.filter(['Summaries'], axis=1)
df_docs_short = df_docs.filter(['Documents'], axis=1)

df_final = pd.concat([df_queries, df_summs_short, df_docs_short], axis=1)

# reorganize dataframe
df_final = df_final[['Titles', 'Query Index', 'Raw Query', 'Summaries', 'Documents']]
df_final = df_final.set_index("Query Index")
df_final.index = df_final.index.astype(int)

df_final.head()
# Out:
#                             Titles  \
# Query Index
# 0                   James Bond.txt
# 1                        Speed.txt
# 2            Official language.txt
# 3             Federal Register.txt
# 4                 Flash memory.txt
#
#                                                      Raw Query  \
# Query Index
# 0            [As of 2018, there have been twenty-four films...
# 1            [[1] The average speed of an object in an inte...
# 2            [[1] Since "the means of expression of a peopl...
# 3            [The Federal Register is compiled by the Offic...
# 4            [Although flash memory is technically a type o...
#
#                                                      Summaries  \
# Query Index
# 0            The James Bond series focuses on a fictional B...
# 1            In everyday use and in kinematics, the speed o...
# 2            An official language is a language that is giv...
# 3            The Federal Register (FR or sometimes Fed. Reg...
# 4            Flash memory is an electronic (solid-state) no...
#
#                                                      Documents
# Query Index
# 0            This article is about the spy series in genera...
# 1            This article is about the property of moving b...
# 2            An official language is a language that is giv...
# 3            Federal Register. Cover. Type. Daily official ...
# 4            For the neuropsychological concept related to ...

# %% [markdown]
# Store all the data

# %%
# store vectorizer
pickle_out = open("out/vectorizer.pickle","wb")
pickle.dump(vectorizer, pickle_out)
pickle_out.close()

# store queries matrix
sp.sparse.save_npz("out/queries_matrix.npz", queries)

# store queries csv
df_final.to_csv("out/wiki_queries.csv")
